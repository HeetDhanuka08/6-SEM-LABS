# %% [markdown]
# ## Heet Dhanuka
# ### B2-34
# ### DIVP PRACTICAL 1

# %%
# Importing library
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# Reading and Displaying lena image
image = cv2.imread('/content/lenna.jpg',1)
cv2_imshow(image)
(h,w,d) = image.shape
print(f"width={w},heigth={h},depth={d}")
# Out:
# <PIL.Image.Image image mode=RGB size=204x192>
# width=204,heigth=192,depth=3

# %%
# Black and White
image1 = cv2.imread('/content/lennab&w.png',1)
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
# Grayscale
image2 = cv2.imread('/content/lenna.jpg',0)
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=L size=204x192>

# %%
# Saving grayscale image
cv2.imwrite('lenna_copy.png',image2)
# Out:
# True

# %%
# Reading pepper image
image3 = cv2.imread('/content/pepper1.jpg',0)

# Display image
cv2_imshow(image3)

# Saving image
cv2.imwrite('pepper1_copy.jpg',image3)
# Out:
# <PIL.Image.Image image mode=L size=269x187>
# True

# %%
# Rotating image
cv2.rotate(image2,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[ 43,  45,  50, ..., 157, 156, 156],
#        [ 58,  66,  76, ..., 157, 156, 156],
#        [ 73,  85, 100, ..., 157, 157, 157],
#        ...,
#        [ 65,  63,  67, ...,  48,  45,  49],
#        [ 56,  56,  64, ...,  49,  44,  46],
#        [ 49,  49,  58, ...,  52,  46,  47]], dtype=uint8)

# %%
cv2.rotate(image2,cv2.ROTATE_90_COUNTERCLOCKWISE)
# Out:
# array([[ 47,  46,  52, ...,  58,  49,  49],
#        [ 46,  44,  49, ...,  64,  56,  56],
#        [ 49,  45,  48, ...,  67,  63,  65],
#        ...,
#        [157, 157, 157, ..., 100,  85,  73],
#        [156, 156, 157, ...,  76,  66,  58],
#        [156, 156, 157, ...,  50,  45,  43]], dtype=uint8)

# %%
cv2.rotate(image2,cv2.ROTATE_180)
# Out:
# array([[ 49,  56,  65, ...,  73,  58,  43],
#        [ 49,  56,  63, ...,  85,  66,  45],
#        [ 58,  64,  67, ..., 100,  76,  50],
#        ...,
#        [ 52,  49,  48, ..., 157, 157, 157],
#        [ 46,  44,  45, ..., 157, 156, 156],
#        [ 47,  46,  49, ..., 157, 156, 156]], dtype=uint8)

# %%
# resizing Image
cv2.resize (image2,(0,0) , fx=0.20 , fy=0.20)
# Out:
# array([[157, 159, 162, ..., 140,  47,  49],
#        [159, 161, 170, ...,  41,  57,  53],
#        [161, 162, 151, ...,  51,  51,  47],
#        ...,
#        [ 38, 171,  79, ..., 100,  90,  84],
#        [ 45, 179,  69, ...,  87, 105,  53],
#        [104, 179,  90, ...,  88,  97,  66]], dtype=uint8)

# %%
cv2.resize(image2,(100,100))
# Out:
# array([[156, 157, 158, ...,  46,  49,  46],
#        [157, 157, 158, ...,  47,  48,  52],
#        [158, 158, 159, ...,  44,  44,  53],
#        ...,
#        [ 84, 105, 129, ...,  85,  65,  66],
#        [ 67, 104, 114, ...,  74,  67,  63],
#        [ 53,  82, 107, ...,  67,  65,  52]], dtype=uint8)

# %%
# Reading and Diaplaying Xray Image
image4 = cv2.imread('/content/xray.jpg',1)
cv2_imshow(image4)
# Out:
# <PIL.Image.Image image mode=RGB size=248x203>

# %%
# Rotating Image
cv2.rotate(image4,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[[ 28,  28,  28],
#         [ 22,  22,  22],
#         [ 17,  17,  17],
#         ...,
#         [168, 168, 168],
#         [158, 158, 158],
#         [ 56,  56,  56]],
#
#        [[ 22,  22,  22],
#         [ 16,  16,  16],
#         [ 10,  10,  10],
#         ...,
#         [169, 169, 169],
#         [168, 168, 168],
#         [ 81,  81,  81]],
#
#        [[ 59,  59,  59],
#         [ 52,  52,  52],
#         [ 45,  45,  45],
#         ...,
#         [174, 174, 174],
#         [176, 176, 176],
#         [100, 100, 100]],
#
#        ...,
#
#        [[129, 129, 129],
#         [114, 114, 114],
#         [ 95,  95,  95],
#         ...,
#         [ 19,  19,  19],
#         [ 10,  10,  10],
#         [  4,   4,   4]],
#
#        [[150, 150, 150],
#         [134, 134, 134],
#         [115, 115, 115],
#         ...,
#         [ 29,  29,  29],
#         [ 16,  16,  16],
#         [  6,   6,   6]],
#
#        [[171, 171, 171],
#         [156, 156, 156],
#         [137, 137, 137],
# ...

# %%
cv2.rotate(image4,cv2.ROTATE_90_COUNTERCLOCKWISE)
# Out:
# array([[[  0,   0,   0],
#         [ 19,  19,  19],
#         [ 40,  40,  40],
#         ...,
#         [137, 137, 137],
#         [156, 156, 156],
#         [171, 171, 171]],
#
#        [[  6,   6,   6],
#         [ 16,  16,  16],
#         [ 29,  29,  29],
#         ...,
#         [115, 115, 115],
#         [134, 134, 134],
#         [150, 150, 150]],
#
#        [[  4,   4,   4],
#         [ 10,  10,  10],
#         [ 19,  19,  19],
#         ...,
#         [ 95,  95,  95],
#         [114, 114, 114],
#         [129, 129, 129]],
#
#        ...,
#
#        [[100, 100, 100],
#         [176, 176, 176],
#         [174, 174, 174],
#         ...,
#         [ 45,  45,  45],
#         [ 52,  52,  52],
#         [ 59,  59,  59]],
#
#        [[ 81,  81,  81],
#         [168, 168, 168],
#         [169, 169, 169],
#         ...,
#         [ 10,  10,  10],
#         [ 16,  16,  16],
#         [ 22,  22,  22]],
#
#        [[ 56,  56,  56],
#         [158, 158, 158],
#         [168, 168, 168],
# ...

# %%
cv2.rotate(image4,cv2.ROTATE_180)
# Out:
# array([[[171, 171, 171],
#         [150, 150, 150],
#         [129, 129, 129],
#         ...,
#         [ 59,  59,  59],
#         [ 22,  22,  22],
#         [ 28,  28,  28]],
#
#        [[156, 156, 156],
#         [134, 134, 134],
#         [114, 114, 114],
#         ...,
#         [ 52,  52,  52],
#         [ 16,  16,  16],
#         [ 22,  22,  22]],
#
#        [[137, 137, 137],
#         [115, 115, 115],
#         [ 95,  95,  95],
#         ...,
#         [ 45,  45,  45],
#         [ 10,  10,  10],
#         [ 17,  17,  17]],
#
#        ...,
#
#        [[ 40,  40,  40],
#         [ 29,  29,  29],
#         [ 19,  19,  19],
#         ...,
#         [174, 174, 174],
#         [169, 169, 169],
#         [168, 168, 168]],
#
#        [[ 19,  19,  19],
#         [ 16,  16,  16],
#         [ 10,  10,  10],
#         ...,
#         [176, 176, 176],
#         [168, 168, 168],
#         [158, 158, 158]],
#
#        [[  0,   0,   0],
#         [  6,   6,   6],
#         [  4,   4,   4],
# ...

# %%
# Reading and Displaying Camera man iamge
image5 = cv2.imread('/content/cameraman.jpg',0)
cv2_imshow(image5)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
# Resizing image
cv2.resize (image5,(0,0) , fx=0.20 , fy=0.20)
# Out:
# array([[158, 158, 160, ..., 155, 155, 156],
#        [157, 157, 158, ..., 151, 151, 150],
#        [154, 158, 160, ..., 152, 152, 154],
#        ...,
#        [128, 128, 110, ..., 156, 135, 111],
#        [139, 124,  88, ..., 119, 117, 150],
#        [129, 121, 115, ...,  87, 107, 114]], dtype=uint8)

# %%
# Rotating Image
cv2.rotate(image5,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[113, 127, 113, ..., 158, 157, 157],
#        [137, 120, 135, ..., 158, 157, 157],
#        [131, 122, 122, ..., 158, 157, 157],
#        ...,
#        [132, 134, 130, ..., 155, 153, 151],
#        [127, 133, 135, ..., 153, 153, 153],
#        [106, 124, 104, ..., 152, 153, 154]], dtype=uint8)

# %%
cv2.rotate(image5,cv2.ROTATE_90_COUNTERCLOCKWISE)
# Out:
# array([[154, 153, 152, ..., 104, 124, 106],
#        [153, 153, 153, ..., 135, 133, 127],
#        [151, 153, 155, ..., 130, 134, 132],
#        ...,
#        [157, 157, 158, ..., 122, 122, 131],
#        [157, 157, 158, ..., 135, 120, 137],
#        [157, 157, 158, ..., 113, 127, 113]], dtype=uint8)

# %%
cv2.rotate(image5,cv2.ROTATE_180)
# Out:
# array([[106, 127, 132, ..., 131, 137, 113],
#        [124, 133, 134, ..., 122, 120, 127],
#        [104, 135, 130, ..., 122, 135, 113],
#        ...,
#        [152, 153, 155, ..., 158, 158, 158],
#        [153, 153, 153, ..., 157, 157, 157],
#        [154, 153, 151, ..., 157, 157, 157]], dtype=uint8)
